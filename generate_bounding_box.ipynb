# %%
from infer_bounding_boxes import infer_all_bboxes
from config import DATA_DIR
from tools import return_files_in_directory
BB_BOX_DIR = DATA_DIR + "/testing/bb_mask"
MASK_DIR = DATA_DIR + "/testing/mask"
infer_all_bboxes(MASK_DIR, BB_BOX_DIR)
# Out:
# Creating Boxes from masks: 10it [00:00, 58.80it/s]

# %%
from PIL import Image
from torchvision.transforms import ToTensor
from tools import visualize
idx = 10

gt_mask = ToTensor()(Image.open(f"/Users/michaelgroeger/workspace/FEA_Internship/publication/boxshrink/data/testing/mask/{idx}.tif"))
bb_mask = ToTensor()(Image.open(f"/Users/michaelgroeger/workspace/FEA_Internship/publication/boxshrink/data/testing/bb_mask/{idx}.png"))
visualize(img=gt_mask.permute(1,2,0), bb_mask=bb_mask.permute(1,2,0))
